# %% [markdown]
# # 🔄 Retomar Experimento 2: Ablation Studies
#
# Este notebook ajuda você a retomar o Experimento 2 de onde parou.
#
# ## ✅ Pré-requisitos
#
# - Ter iniciado o Experimento 2 anteriormente
# - Ter o checkpoint `teacher_CIFAR10.pt` salvo no Google Drive
# - GPU ativada no Colab (Runtime > Change runtime type > GPU)
#
# ---

# %% [markdown]
# ## 📁 Passo 1: Montar Google Drive

# %%
from google.colab import drive
import os

# Montar Google Drive
drive.mount('/content/drive')

# Verificar se está montado
if os.path.exists('/content/drive/MyDrive'):
    print("✅ Google Drive montado com sucesso!")
else:
    print("❌ Erro ao montar Google Drive")

# %% [markdown]
# ## 🔍 Passo 2: Verificar Estado do Experimento

# %%
# Navegar para a pasta de resultados
results_dir = '/content/drive/MyDrive/HPM-KD_Results/exp02_ablation_full'

print("=" * 80)
print("VERIFICANDO ESTADO DO EXPERIMENTO 2")
print("=" * 80)
print(f"\nDiretório: {results_dir}\n")

# Verificar estrutura
# !ls -lh {results_dir}

print("\n" + "=" * 80)
print("MODELOS SALVOS")
print("=" * 80)
# !ls -lh {results_dir}/models/ 2>/dev/null || echo "❌ Pasta models/ não encontrada"

print("\n" + "=" * 80)
print("EXPERIMENTOS COMPLETADOS (CSVs)")
print("=" * 80)
# !ls -1 {results_dir}/*.csv 2>/dev/null || echo "⚠️  Nenhum CSV encontrado"

print("\n" + "=" * 80)
print("FIGURAS GERADAS")
print("=" * 80)
# !ls -1 {results_dir}/figures/*.png 2>/dev/null || echo "⚠️  Nenhuma figura encontrada"

# %% [markdown]
# ## 🔬 Passo 3: Verificar Checkpoint do Teacher

# %%
import torch

checkpoint_path = f"{results_dir}/models/teacher_CIFAR10.pt"

print("=" * 80)
print("VERIFICANDO CHECKPOINT DO TEACHER")
print("=" * 80)
print(f"\nCaminho: {checkpoint_path}\n")

try:
    checkpoint = torch.load(checkpoint_path, map_location='cpu')

    print("✅ CHECKPOINT VÁLIDO!")
    print(f"\n   🎯 Acurácia: {checkpoint['accuracy']:.2f}%")
    print(f"   ⏱️  Tempo de treino: {checkpoint['train_time']:.2f}s")
    print(f"   📅 Timestamp: {checkpoint['timestamp']}")

    if 'metadata' in checkpoint:
        print(f"   📝 Metadata: {checkpoint['metadata']}")

    print("\n💡 Você pode continuar de onde parou sem retreinar o teacher!")

except FileNotFoundError:
    print("❌ CHECKPOINT NÃO ENCONTRADO")
    print("\n   O script treinará o teacher do zero (~30-45 minutos).")

except Exception as e:
    print(f"❌ ERRO AO CARREGAR CHECKPOINT: {e}")
    print("\n   Solução: Delete o arquivo corrompido e retreine:")
    print(f"   !rm {checkpoint_path}")

# %% [markdown]
# ## 📦 Passo 4: Clonar/Atualizar Repositório

# %%
import os

# Verificar se já clonou
if os.path.exists('/content/papers-deepbridge'):
    print("✅ Repositório já existe, atualizando...")
    # !cd /content/papers-deepbridge && git pull
else:
    print("📥 Clonando repositório...")
    # IMPORTANTE: Atualize com a URL correta do seu repositório
    # !git clone https://github.com/seu-usuario/papers-deepbridge.git /content/papers-deepbridge

print("\n✅ Repositório pronto!")

# %% [markdown]
# ## 📚 Passo 5: Instalar Dependências

# %%
print("📦 Instalando PyTorch...")
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

print("📦 Instalando bibliotecas de visualização...")
# !pip install -q matplotlib seaborn pandas numpy scipy tqdm

print("\n✅ Dependências instaladas!")

# Verificar PyTorch
import torch
print(f"\n🔍 PyTorch versão: {torch.__version__}")
print(f"🔍 CUDA disponível: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"🔍 GPU: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## 🚀 Passo 6: Retomar Experimento

# %%
# Configuração
DATASET = 'CIFAR10'
MODE = 'full'  # 'quick' ou 'full'
GPU = 0
OUTPUT = results_dir

print("=" * 80)
print("RETOMANDO EXPERIMENTO 2: ABLATION STUDIES")
print("=" * 80)
print(f"\nConfiguração:")
print(f"  - Dataset: {DATASET}")
print(f"  - Modo: {MODE}")
print(f"  - GPU: {GPU}")
print(f"  - Output: {OUTPUT}")
print("\n" + "=" * 80)
print("INICIANDO...")
print("=" * 80 + "\n")

# Executar experimento
# !cd /content/papers-deepbridge/01_HPM-KD_Framework/POR/experiments/scripts && \
python3 02_ablation_studies.py \
    --mode {MODE} \
    --dataset {DATASET} \
    --gpu {GPU} \
    --output "{OUTPUT}"

# %% [markdown]
# ## 📊 Passo 7: Monitorar Progresso (Executar em Paralelo)

# %%
import time
from IPython.display import clear_output

print("🔄 Monitorando progresso (Ctrl+C para parar)...\n")

try:
    while True:
        clear_output(wait=True)

        print("=" * 80)
        print("PROGRESSO DO EXPERIMENTO 2")
        print("=" * 80)

        # Arquivos recentes
        print("\n📁 ARQUIVOS RECENTES:")
        # !ls -lth {results_dir} | head -10

        # CSVs gerados
        print("\n📊 EXPERIMENTOS COMPLETADOS:")
        # !ls -1 {results_dir}/*.csv 2>/dev/null | sed 's|.*/||' || echo "  ⚠️  Nenhum CSV gerado ainda"

        # Figuras
        print("\n🖼️ FIGURAS GERADAS:")
        # !ls -1 {results_dir}/figures/*.png 2>/dev/null | sed 's|.*/||' || echo "  ⚠️  Nenhuma figura gerada ainda"

        # GPU usage
        print("\n🔥 USO DA GPU:")
        # !nvidia-smi --query-gpu=utilization.gpu,memory.used,memory.total --format=csv

        print("\n" + "=" * 80)
        print(f"Atualizado em: {time.strftime('%H:%M:%S')}")
        print("=" * 80)

        time.sleep(30)  # Atualiza a cada 30 segundos

except KeyboardInterrupt:
    print("\n⏸️  Monitoramento interrompido")

# %% [markdown]
# ## 📈 Passo 8: Visualizar Resultados (Após Conclusão)

# %%
import pandas as pd
from IPython.display import Image, display
import os

print("=" * 80)
print("RESULTADOS DO EXPERIMENTO 2")
print("=" * 80)

# Listar CSVs
csv_files = [
    ('exp05_component_ablation.csv', 'Experimento 5: Component Ablation'),
    ('exp06_component_interactions.csv', 'Experimento 6: Component Interactions'),
    ('exp07_hyperparameter_sensitivity.csv', 'Experimento 7: Hyperparameter Sensitivity'),
    ('exp08_progressive_chain.csv', 'Experimento 8: Progressive Chain Length'),
    ('exp09_num_teachers.csv', 'Experimento 9: Number of Teachers')
]

for csv_file, description in csv_files:
    csv_path = f"{results_dir}/{csv_file}"

    if os.path.exists(csv_path):
        print(f"\n{'=' * 80}")
        print(f"{description}")
        print(f"{'=' * 80}")

        df = pd.read_csv(csv_path)
        display(df)
    else:
        print(f"\n⚠️  {description}: Não completado")

# Mostrar figuras
print("\n" + "=" * 80)
print("FIGURAS GERADAS")
print("=" * 80)

figures_dir = f"{results_dir}/figures"
if os.path.exists(figures_dir):
    for img_file in sorted(os.listdir(figures_dir)):
        if img_file.endswith('.png'):
            print(f"\n{'=' * 80}")
            print(f"{img_file}")
            print(f"{'=' * 80}")
            display(Image(filename=f"{figures_dir}/{img_file}"))
else:
    print("⚠️  Nenhuma figura encontrada")

# %% [markdown]
# ## 💾 Passo 9: Baixar Resultados (Opcional)

# %%
from google.colab import files
import zipfile

# Criar ZIP com todos os resultados
zip_path = '/content/exp02_results.zip'

print("📦 Criando arquivo ZIP com os resultados...")

with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Adicionar CSVs
    for csv_file, _ in csv_files:
        csv_path = f"{results_dir}/{csv_file}"
        if os.path.exists(csv_path):
            zipf.write(csv_path, csv_file)

    # Adicionar figuras
    if os.path.exists(figures_dir):
        for img_file in os.listdir(figures_dir):
            if img_file.endswith('.png'):
                zipf.write(f"{figures_dir}/{img_file}", f"figures/{img_file}")

print(f"✅ ZIP criado: {zip_path}")

# Baixar
print("\n📥 Baixando arquivo...")
files.download(zip_path)

print("✅ Download concluído!")

# %% [markdown]
# ---
#
# ## 🎉 Conclusão
#
# Após executar todas as células acima, você terá:
#
# - ✅ Experimento 2 retomado de onde parou
# - ✅ Todos os 5 sub-experimentos completados
# - ✅ Figuras e tabelas geradas
# - ✅ Resultados salvos no Google Drive
#
# ### Próximos Passos
#
# 1. Analisar os resultados CSV
# 2. Interpretar as figuras geradas
# 3. Escrever a seção de Ablation Studies do paper
# 4. Comparar com os resultados do Experimento 1
#
# ---
#
# *Criado em: 17 de Novembro de 2025*
